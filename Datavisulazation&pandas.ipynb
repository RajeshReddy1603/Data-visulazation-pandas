# %%
import matplotlib .pyplot as plt
a=[10,90]
b=[100,200]
plt.title("these is a graph")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.plot(a,b,marker="*")

# %%
import matplotlib.pyplot as plt
products=["amazon","netflix","aha"]
values=[200,500,100]
plt.title("these is a bar graph")
plt.xlabel("products")
plt.ylabel("values")
plt.barh(products,values)
# Out:
# <BarContainer object of 3 artists>

# %%
import matplotlib .pyplot as plt
a=[10,20,30,40,50,60,70,10,10,20,20]
plt.hist(a,bins=11,width=1.0)
# Out:
# (array([3., 3., 0., 1., 0., 1., 0., 1., 0., 1., 1.]),
#  array([10.        , 15.45454545, 20.90909091, 26.36363636, 31.81818182,
#         37.27272727, 42.72727273, 48.18181818, 53.63636364, 59.09090909,
#         64.54545455, 70.        ]),
#  <BarContainer object of 11 artists>)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("sales31.csv")
df
plt.title("bar graph")
plt.xlabel("prod name")
plt.ylabel("prod cost")
plt.bar(df["prod name"],df["prod cost"])
# Out:
# <BarContainer object of 10 artists>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("sales3.csv")
df
plt.title("these is a graph")
plt.xlabel("cust name")
plt.ylabel("prod name")
plt.bar(df["cust name"],df["prod name"])
# Out:
# <BarContainer object of 30 artists>

# %%
import matplotlib.pyplot as plt
products=["amazon","netflix","aha"]
sales=[250,500,100]
plt.pie(sales,labels=products,shadow=True,explode=(0.05,0.05,0.05),autopct='%1.2f%%')
plt.legend()
plt.axis('equal')
# Out:
# (np.float64(-1.146967225139081),
#  np.float64(1.1510803173739963),
#  np.float64(-1.1296323604221845),
#  np.float64(1.1432108615182417))

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("sales31.csv")
df
plt.pie(df["prod cost"],labels=df["prod name"],autopct="%1.1f%%",shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x26112f73110>,
# ...
#  [Text(1.041330316915327, 0.3544448773406451, 'LG Mobile'),
#   Text(0.6224451663970267, 0.9069520465983734, 'Apple iPad 10.2-inch'),
#   Text(-0.09829601658644452, 1.095599330559871, '34in Ultrawide Monitor'),
#   Text(-0.7622039986195379, 0.7931236123634119, 'iPhone 11'),
#   Text(-1.086114365012983, 0.1742285456302868, 'Bose SoundSport Headphones'),
#   Text(-0.9562489222840177, -0.5436800517130042, '20in Monitor'),
#   Text(-0.4758606843133281, -0.9917442256574279, 'iPhone 8'),
#   Text(0.12005452705387908, -1.0934289691305374, '27in 4K Gaming Monitor'),
#   Text(0.6797106505667861, -0.8648661350209502, 'iPhone 9'),
#   Text(1.046498646207062, -0.3388813708169668, '20in Monitor')],
#  [Text(0.5679983546810873, 0.19333356945853367, '10.4%'),
#   Text(0.33951554530746914, 0.49470111632638536, '10.0%'),
#   Text(-0.053616009047151546, 0.5975996348508387, '12.0%'),
#   Text(-0.415747635610657, 0.4326128794709519, '9.5%'),
# ...

# %%
import matplotlib.pyplot as plt
a=[10,20,30,40,50,60,70,80]
b=[50,60,70,80,90,100,20,50]
plt.title("these is a scatter")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.scatter(a,b)

# %%
import seaborn as sns
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
cond1=df["sex"]=="male"

# %%
df[cond1]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df["embark_town"].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df1=df.dropna()

# %%
df1.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import os
a="./daniel"
all_files=os.listdir(a)
all_files
# Out:
# ['apr_sales.csv',
#  'aug_sales.csv',
#  'dec_sales.csv',
#  'feb_sales.csv',
#  'fun.jpg',
#  'jan_sales.csv',
#  'jul_sales.csv',
#  'jun_sales.csv',
#  'mar_sales.csv',
#  'may_sales.csv',
#  'nov_sales.csv',
#  'oct_sales.csv',
#  'progress.txt',
#  'sep_sales.csv',
#  'status.xlsx']

# %%
import os
all_files=os.listdir(a)
csv_files=filter(lambda a : a.endswith(".csv"),all_files)
list(csv_files)
# Out:
# ['apr_sales.csv',
#  'aug_sales.csv',
#  'dec_sales.csv',
#  'feb_sales.csv',
#  'jan_sales.csv',
#  'jul_sales.csv',
#  'jun_sales.csv',
#  'mar_sales.csv',
#  'may_sales.csv',
#  'nov_sales.csv',
#  'oct_sales.csv',
#  'sep_sales.csv']

# %%
import os
import glob
import pandas as pd
a="./daniel"
all_files=os.path.join(a,"*csv")
csv_files=glob.glob(all_files)
df=[pd.read_csv(file)
    for file in csv_files]
result=pd.concat(df,ignore_index=False)
result
# Out:
#     Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0       1320          Venu           23      LG ThinQ Refrigerator
# 1       1321  Jaya Chandra           21  Bose SoundSport Headphones
# 2       1322   Mallikarjun           13    Apple Airpods Headphones
# 3       1323        Siddhu           18      Samsung Galaxy S9 Plus
# 4       1324        Daniel            6                    iPhone 8
# ..       ...           ...          ...                         ...
# 4       1819        Daniel            6          LG Washing Machine
# 5       1820       Neelima           19                20in Monitor
# 6       1821       Karteek            4                20in Monitor
# 7       1822  Jaya Chandra           21      LG ThinQ Refrigerator
# 8       1823    Chaithanya           14            27in FHD Monitor
#
#     Product_Cost             Date
# 0          55000   4/11/2019 9:00
# 1          63000  4/13/2019 10:00
# 2          69999  4/13/2019 11:00
# ...

# %%
result
a={
    "Product_Cost":["sum","max","min"]
}
out=result.groupby(["Date","Product_Name"]).agg(a)
out
# Out:
#                                          Product_Cost
#                                                   sum    max    min
# Date          Product_Name
# 1/1/2019 0:00 27in FHD Monitor                  59000  59000  59000
# 1/1/2019 1:00 iPhone 11                         69000  69000  69000
# 1/2/2019 2:00 Bose SoundSport Headphones        65999  65999  65999
# 1/2/2019 3:00 Apple iPad 10.2-inch              63999  63999  63999
# 1/2/2019 4:00 Google Phone                      63999  63999  63999
# ...                                               ...    ...    ...
# 9/3/2019 4:00 LG Washing Machine                50000  50000  50000
# 9/3/2019 5:00 20in Monitor                      55000  55000  55000
# 9/3/2019 6:00 20in Monitor                      50000  50000  50000
# 9/3/2019 7:00 LG ThinQ Refrigerator             75999  75999  75999
# 9/3/2019 8:00 27in FHD Monitor                  55000  55000  55000
#
# [108 rows x 3 columns]

# %%
output=result.groupby(["Customer_Name","Product_Name"],as_index=False)["Product_Name"]
final=output.value_counts()
final
# Out:
#    Customer_Name              Product_Name  count
# 0         Balaji  Apple Airpods Headphones      1
# 1         Balaji              Google Phone      1
# 2         Balaji                 LG Mobile      1
# 3         Balaji    Samsung Galaxy S9 Plus      1
# 4         Balaji                 iPhone 11      1
# ..           ...                       ...    ...
# 92          Venu                  iPhone 9      1
# 93         Vijay             Flatscreen TV      1
# 94         Vijay        Macbook Pro Laptop      1
# 95         Vinay          27in FHD Monitor      1
# 96         Vinay                 LG Mobile      1
#
# [97 rows x 3 columns]

# %%
import pandas as pd
df=pd.read_csv("sales4.csv")
df
# Out:
#         Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0           1023         Venki           15            27in FHD Monitor
# 1           1024    Chaithanya           14                   iPhone 11
# 2           1025        Shahid           20  Bose SoundSport Headphones
# 3           1026         Veeru            3        Apple iPad 10.2-inch
# 4           1027          Venu           23                Google Phone
# ...          ...           ...          ...                         ...
# 299995    301018       Karteek            4        Apple iPad 10.2-inch
# 299996    301019         Veeru            3          Macbook Pro Laptop
# 299997    301020        Harsha            5          LG Washing Machine
# 299998    301021    Nireekshan            1                   LG Mobile
# 299999    301022       Pradhan           17      34in Ultrawide Monitor
#
#         Product_Cost
# 0              59000
# 1              69000
# 2              65999
# ...

# %%
cond1=df["Product_Cost"]>65000
(df[cond1])
# Out:
#         Order_Id Customer_Name  Customer_Id                Product_Name  \
# 1           1024    Chaithanya           14                   iPhone 11
# 2           1025        Shahid           20  Bose SoundSport Headphones
# 11          1034         Tarun           11          Samsung Galaxy S20
# 13          1036    Chaithanya           14      LG ThinQ Refrigerator
# 17          1040       Sumanth           22                    iPhone 8
# ...          ...           ...          ...                         ...
# 299982    301005         Tarun           11          Samsung Galaxy S20
# 299983    301006         Shafi           25      27in 4K Gaming Monitor
# 299985    301008         Venki           15    Apple Airpods Headphones
# 299988    301011         Venki           15                Google Phone
# 299990    301013        Balaji           12                   iPhone 11
#
#         Product_Cost
# 1              69000
# 2              65999
# 11             69999
# ...

# %%
cond1=df["Customer_Name"]=="Chaithanya"
cond2=df["Product_Name"]=="Samsung Galaxy S20"
df1=df.loc[cond1&cond2]
df1
# Out:
#         Order_Id Customer_Name  Customer_Id        Product_Name  Product_Cost
# 133         1156    Chaithanya           14  Samsung Galaxy S20         55000
# 1192        2215    Chaithanya           14  Samsung Galaxy S20         55000
# 1233        2256    Chaithanya           14  Samsung Galaxy S20         65999
# 2575        3598    Chaithanya           14  Samsung Galaxy S20         55999
# 4051        5074    Chaithanya           14  Samsung Galaxy S20         65000
# ...          ...           ...          ...                 ...           ...
# 297223    298246    Chaithanya           14  Samsung Galaxy S20         75999
# 297757    298780    Chaithanya           14  Samsung Galaxy S20         51999
# 298704    299727    Chaithanya           14  Samsung Galaxy S20         63000
# 298992    300015    Chaithanya           14  Samsung Galaxy S20         59000
# 299840    300863    Chaithanya           14  Samsung Galaxy S20         63000
#
# [610 rows x 5 columns]

# %%
a=["LG ThinQ Refrigerator","iPhone 8","Google Phone"]
b=df["Product_Name"].isin(a)
df1=df[b]
df1
# Out:
#         Order_Id Customer_Name  Customer_Id  Product_Name  Product_Cost
# 4           1027          Venu           23  Google Phone         63999
# 12          1035         Kedar            2  Google Phone         55999
# 17          1040       Sumanth           22      iPhone 8         65999
# 19          1042   Mallikarjun           13  Google Phone         65999
# 30          1053    Chaithanya           14      iPhone 8         60000
# ...          ...           ...          ...           ...           ...
# 299938    300961         Kedar            2      iPhone 8         75000
# 299966    300989          Venu           23      iPhone 8         51999
# 299970    300993    Nireekshan            1      iPhone 8         60000
# 299978    301001          Venu           23  Google Phone         65999
# 299988    301011         Venki           15  Google Phone         65999
#
# [30322 rows x 5 columns]

# %%
import pandas as pd
df=pd.read_csv("sales4.csv")
df
# Out:
#         Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0           1023         Venki           15            27in FHD Monitor
# 1           1024    Chaithanya           14                   iPhone 11
# 2           1025        Shahid           20  Bose SoundSport Headphones
# 3           1026         Veeru            3        Apple iPad 10.2-inch
# 4           1027          Venu           23                Google Phone
# ...          ...           ...          ...                         ...
# 299995    301018       Karteek            4        Apple iPad 10.2-inch
# 299996    301019         Veeru            3          Macbook Pro Laptop
# 299997    301020        Harsha            5          LG Washing Machine
# 299998    301021    Nireekshan            1                   LG Mobile
# 299999    301022       Pradhan           17      34in Ultrawide Monitor
#
#         Product_Cost
# 0              59000
# 1              69000
# 2              65999
# ...

# %%
a=df.index[20:90]
b=["Customer_Name","Product_Name"]
df1=df.loc[a,b]
df1
# Out:
#    Customer_Name              Product_Name
# 20         Vinay  Apple Airpods Headphones
# 21       Sumanth        Samsung Galaxy S20
# 22       Lavanya                 iPhone 7s
# 23     Madhurima        Macbook Pro Laptop
# 24         Shafi        LG Washing Machine
# ..           ...                       ...
# 85         Vijay        Macbook Pro Laptop
# 86          Venu                  iPhone 9
# 87        Daniel                  iPhone 8
# 88         Kedar        Macbook Pro Laptop
# 89        Siddhu        LG Washing Machine
#
# [70 rows x 2 columns]

# %%
import pandas as pd
df1=pd.read_csv("sales3.csv")
df2=pd.read_csv("sales31.csv")
inner_merge=pd.merge(df1,df2,on="prod name",how="left")
inner_merge
# Out:
#     ord id_x  cust name_x  cust id_x                   prod name  prod cost_x  \
# 0     192837        Veeru          3                   LG Mobile        65999
# 1     192838      Neelima         19        Apple iPad 10.2-inch        63000
# 2     192839       Balaji         12      34in Ultrawide Monitor        75999
# 3     192840       Shahid         20                   iPhone 11        60000
# 4     192841        Vinay         10  Bose SoundSport Headphones        69999
# 5     192842        Vinay         10                20in Monitor        65999
# 6     192842        Vinay         10                20in Monitor        65999
# 7     192843       Balaji         12                    iPhone 8        55999
# 8     192844   Nireekshan          1      27in 4K Gaming Monitor        55999
# 9     192845         Venu         23                    iPhone 9        55999
# 10    192846        Veeru          3                20in Monitor        63000
# ...

# %%
import pandas as pd
a=[[10,11],
   [12,13]]
b=[[14,15],
   [16,17]]
x=["name","age"]
df1=pd.DataFrame(a,columns=x)
df2=pd.DataFrame(b,columns=x)
y=[df1,df2]
result=pd.concat(y,ignore_index=True)
result
# Out:
#    name  age
# 0    10   11
# 1    12   13
# 2    14   15
# 3    16   17

# %%
import pandas as pd
a=[[10,11],
   [12,13]]
b=[[14,15],
   [16,17],
   [18,19]]
x=["a","b"]
y=["c","d"]
df1=pd.DataFrame(a,columns=x)
df2=pd.DataFrame(b,columns=y)
z=[df1,df2]
result=pd.concat(z,axis=1)
result
# Out:
#       a     b   c   d
# 0  10.0  11.0  14  15
# 1  12.0  13.0  16  17
# 2   NaN   NaN  18  19

# %%
import pandas as pd
df=pd.read_csv("sales8.csv")
df
# Out:
#     Order Id Customer name  Customer Id                Product name  \
# 0     192837         Veeru            3                   LG Mobile
# 1     192838       Neelima           19        Apple iPad 10.2-inch
# 2     192839        Balaji           12      34in Ultrawide Monitor
# 3     192840        Shahid           20                   iPhone 11
# 4     192841         Vinay           10  Bose SoundSport Headphones
# 5     192842         Vinay           10                20in Monitor
# 6     192843        Balaji           12                    iPhone 8
# 7     192844    Nireekshan            1      27in 4K Gaming Monitor
# 8     192845          Venu           23                    iPhone 9
# 9     192846         Veeru            3                20in Monitor
# 10    192847     Madhurima            7               Flatscreen TV
# 11    192848         Kedar            2               Flatscreen TV
# 12    192849          Venu           23          Samsung Galaxy S20
# ...

# %%
df["finalrow"]="value"
df
# Out:
#     Order Id Customer name  Customer Id                Product name  \
# 0     192837         Veeru            3                   LG Mobile
# 1     192838       Neelima           19        Apple iPad 10.2-inch
# 2     192839        Balaji           12      34in Ultrawide Monitor
# 3     192840        Shahid           20                   iPhone 11
# 4     192841         Vinay           10  Bose SoundSport Headphones
# 5     192842         Vinay           10                20in Monitor
# 6     192843        Balaji           12                    iPhone 8
# 7     192844    Nireekshan            1      27in 4K Gaming Monitor
# 8     192845          Venu           23                    iPhone 9
# 9     192846         Veeru            3                20in Monitor
# 10    192847     Madhurima            7               Flatscreen TV
# 11    192848         Kedar            2               Flatscreen TV
# 12    192849          Venu           23          Samsung Galaxy S20
# ...

# %%
df["totalvalue"]=df["Product cost"]*df["Quantity"]
df
# Out:
#     Order Id Customer name  Customer Id                Product name  \
# 0     192837         Veeru            3                   LG Mobile
# 1     192838       Neelima           19        Apple iPad 10.2-inch
# 2     192839        Balaji           12      34in Ultrawide Monitor
# 3     192840        Shahid           20                   iPhone 11
# 4     192841         Vinay           10  Bose SoundSport Headphones
# 5     192842         Vinay           10                20in Monitor
# 6     192843        Balaji           12                    iPhone 8
# 7     192844    Nireekshan            1      27in 4K Gaming Monitor
# 8     192845          Venu           23                    iPhone 9
# 9     192846         Veeru            3                20in Monitor
# 10    192847     Madhurima            7               Flatscreen TV
# 11    192848         Kedar            2               Flatscreen TV
# 12    192849          Venu           23          Samsung Galaxy S20
# ...

# %%
a="totalvalue"
df.insert(3,"newvalue",a)
df
# Out:
#     Order Id Customer name  Customer Id    newvalue  \
# 0     192837         Veeru            3  totalvalue
# 1     192838       Neelima           19  totalvalue
# 2     192839        Balaji           12  totalvalue
# 3     192840        Shahid           20  totalvalue
# 4     192841         Vinay           10  totalvalue
# 5     192842         Vinay           10  totalvalue
# 6     192843        Balaji           12  totalvalue
# 7     192844    Nireekshan            1  totalvalue
# 8     192845          Venu           23  totalvalue
# 9     192846         Veeru            3  totalvalue
# 10    192847     Madhurima            7  totalvalue
# 11    192848         Kedar            2  totalvalue
# 12    192849          Venu           23  totalvalue
# 13    192850       Neelima           19  totalvalue
# 14    192851        Daniel            6  totalvalue
# 15    192852         Veeru            3  totalvalue
# 16    192853       Lavanya           16  totalvalue
# ...

# %%
a="additionvalue"
df.insert(4,"twovalues",a)
df
# Out:
#     Order Id Customer name  Customer Id    newvalue      twovalues  \
# 0     192837         Veeru            3  totalvalue  additionvalue
# 1     192838       Neelima           19  totalvalue  additionvalue
# 2     192839        Balaji           12  totalvalue  additionvalue
# 3     192840        Shahid           20  totalvalue  additionvalue
# 4     192841         Vinay           10  totalvalue  additionvalue
# 5     192842         Vinay           10  totalvalue  additionvalue
# 6     192843        Balaji           12  totalvalue  additionvalue
# 7     192844    Nireekshan            1  totalvalue  additionvalue
# 8     192845          Venu           23  totalvalue  additionvalue
# 9     192846         Veeru            3  totalvalue  additionvalue
# 10    192847     Madhurima            7  totalvalue  additionvalue
# 11    192848         Kedar            2  totalvalue  additionvalue
# 12    192849          Venu           23  totalvalue  additionvalue
# ...

# %%
df1=df.drop(columns="newvalue")
df1
# Out:
#     Order Id Customer name  Customer Id      twovalues  \
# 0     192837         Veeru            3  additionvalue
# 1     192838       Neelima           19  additionvalue
# 2     192839        Balaji           12  additionvalue
# 3     192840        Shahid           20  additionvalue
# 4     192841         Vinay           10  additionvalue
# 5     192842         Vinay           10  additionvalue
# 6     192843        Balaji           12  additionvalue
# 7     192844    Nireekshan            1  additionvalue
# 8     192845          Venu           23  additionvalue
# 9     192846         Veeru            3  additionvalue
# 10    192847     Madhurima            7  additionvalue
# 11    192848         Kedar            2  additionvalue
# 12    192849          Venu           23  additionvalue
# 13    192850       Neelima           19  additionvalue
# 14    192851        Daniel            6  additionvalue
# 15    192852         Veeru            3  additionvalue
# ...

# %%
df1
# Out:
#     Order Id Customer name  Customer Id      twovalues  \
# 0     192837         Veeru            3  additionvalue
# 1     192838       Neelima           19  additionvalue
# 2     192839        Balaji           12  additionvalue
# 3     192840        Shahid           20  additionvalue
# 4     192841         Vinay           10  additionvalue
# 5     192842         Vinay           10  additionvalue
# 6     192843        Balaji           12  additionvalue
# 7     192844    Nireekshan            1  additionvalue
# 8     192845          Venu           23  additionvalue
# 9     192846         Veeru            3  additionvalue
# 10    192847     Madhurima            7  additionvalue
# 11    192848         Kedar            2  additionvalue
# 12    192849          Venu           23  additionvalue
# 13    192850       Neelima           19  additionvalue
# 14    192851        Daniel            6  additionvalue
# 15    192852         Veeru            3  additionvalue
# ...

# %%
df2=df1.drop(["twovalues","finalrow"],axis=1)
df2
# Out:
#     Order Id Customer name  Customer Id                Product name  \
# 0     192837         Veeru            3                   LG Mobile
# 1     192838       Neelima           19        Apple iPad 10.2-inch
# 2     192839        Balaji           12      34in Ultrawide Monitor
# 3     192840        Shahid           20                   iPhone 11
# 4     192841         Vinay           10  Bose SoundSport Headphones
# 5     192842         Vinay           10                20in Monitor
# 6     192843        Balaji           12                    iPhone 8
# 7     192844    Nireekshan            1      27in 4K Gaming Monitor
# 8     192845          Venu           23                    iPhone 9
# 9     192846         Veeru            3                20in Monitor
# 10    192847     Madhurima            7               Flatscreen TV
# 11    192848         Kedar            2               Flatscreen TV
# 12    192849          Venu           23          Samsung Galaxy S20
# ...

# %%
df2
# Out:
#     Order Id Customer name  Customer Id                Product name  \
# 0     192837         Veeru            3                   LG Mobile
# 1     192838       Neelima           19        Apple iPad 10.2-inch
# 2     192839        Balaji           12      34in Ultrawide Monitor
# 3     192840        Shahid           20                   iPhone 11
# 4     192841         Vinay           10  Bose SoundSport Headphones
# 5     192842         Vinay           10                20in Monitor
# 6     192843        Balaji           12                    iPhone 8
# 7     192844    Nireekshan            1      27in 4K Gaming Monitor
# 8     192845          Venu           23                    iPhone 9
# 9     192846         Veeru            3                20in Monitor
# 10    192847     Madhurima            7               Flatscreen TV
# 11    192848         Kedar            2               Flatscreen TV
# 12    192849          Venu           23          Samsung Galaxy S20
# ...

# %%
df3=df2.drop([3,10,15,20],axis=0)
df3=df2.reset_index(drop=True)
df3
# Out:
#     Order Id Customer name  Customer Id                Product name  \
# 0     192837         Veeru            3                   LG Mobile
# 1     192838       Neelima           19        Apple iPad 10.2-inch
# 2     192839        Balaji           12      34in Ultrawide Monitor
# 3     192840        Shahid           20                   iPhone 11
# 4     192841         Vinay           10  Bose SoundSport Headphones
# 5     192842         Vinay           10                20in Monitor
# 6     192843        Balaji           12                    iPhone 8
# 7     192844    Nireekshan            1      27in 4K Gaming Monitor
# 8     192845          Venu           23                    iPhone 9
# 9     192846         Veeru            3                20in Monitor
# 10    192847     Madhurima            7               Flatscreen TV
# 11    192848         Kedar            2               Flatscreen TV
# 12    192849          Venu           23          Samsung Galaxy S20
# ...

# %%
import pandas as pd
df=pd.read_csv("sales7_dates.csv",parse_dates=["Pur_Date"])
df
# Out:
#       Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0         1023         Venki           15            27in FHD Monitor
# 1         1024    Chaithanya           14                   iPhone 11
# 2         1025        Shahid           20  Bose SoundSport Headphones
# 3         1026         Veeru            3        Apple iPad 10.2-inch
# 4         1027          Venu           23                Google Phone
# ...        ...           ...          ...                         ...
# 9994     11017       Karteek            4                20in Monitor
# 9995     11018         Vinay           10    Apple Airpods Headphones
# 9996     11019       Neelima           19      LG ThinQ Refrigerator
# 9997     11020        Siddhu           18                   iPhone 7s
# 9998     11021         Tarun           11      34in Ultrawide Monitor
#
#       Product_Cost            Pur_Date
# 0            59000 2019-01-01 00:00:00
# 1            69000 2019-01-01 01:00:00
# ...

# %%
df.set_index("Pur_Date",inplace=True)
days_10=df.last("10D")
days_10
# Out:
# C:\Users\rajes\AppData\Local\Temp\ipykernel_9668\2807312136.py:2: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   days_10=df.last("10D")
#                      Order_Id Customer_Name  Customer_Id  \
# Pur_Date
# 2020-02-11 15:00:00     10782        Harsha            5
# 2020-02-11 16:00:00     10783         Veeru            3
# 2020-02-11 17:00:00     10784         Vinay           10
# 2020-02-11 18:00:00     10785  Jaya Chandra           21
# 2020-02-11 19:00:00     10786        Shahid           20
# ...                       ...           ...          ...
# 2020-02-21 10:00:00     11017       Karteek            4
# 2020-02-21 11:00:00     11018         Vinay           10
# 2020-02-21 12:00:00     11019       Neelima           19
# 2020-02-21 13:00:00     11020        Siddhu           18
# 2020-02-21 14:00:00     11021         Tarun           11
#
# ...

# %%
import pandas as pd
df=pd.read_csv("sales7_dates.csv",parse_dates=["Pur_Date"])
df
# Out:
#       Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0         1023         Venki           15            27in FHD Monitor
# 1         1024    Chaithanya           14                   iPhone 11
# 2         1025        Shahid           20  Bose SoundSport Headphones
# 3         1026         Veeru            3        Apple iPad 10.2-inch
# 4         1027          Venu           23                Google Phone
# ...        ...           ...          ...                         ...
# 9994     11017       Karteek            4                20in Monitor
# 9995     11018         Vinay           10    Apple Airpods Headphones
# 9996     11019       Neelima           19      LG ThinQ Refrigerator
# 9997     11020        Siddhu           18                   iPhone 7s
# 9998     11021         Tarun           11      34in Ultrawide Monitor
#
#       Product_Cost            Pur_Date
# 0            59000 2019-01-01 00:00:00
# 1            69000 2019-01-01 01:00:00
# ...

# %%
df.set_index("Pur_Date",inplace=True)
df
days_10=df.last("10D")
days_10
# Out:
# C:\Users\rajes\AppData\Local\Temp\ipykernel_9668\2892906280.py:3: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   days_10=df.last("10D")
#                      Order_Id Customer_Name  Customer_Id  \
# Pur_Date
# 2020-02-11 15:00:00     10782        Harsha            5
# 2020-02-11 16:00:00     10783         Veeru            3
# 2020-02-11 17:00:00     10784         Vinay           10
# 2020-02-11 18:00:00     10785  Jaya Chandra           21
# 2020-02-11 19:00:00     10786        Shahid           20
# ...                       ...           ...          ...
# 2020-02-21 10:00:00     11017       Karteek            4
# 2020-02-21 11:00:00     11018         Vinay           10
# 2020-02-21 12:00:00     11019       Neelima           19
# 2020-02-21 13:00:00     11020        Siddhu           18
# 2020-02-21 14:00:00     11021         Tarun           11
#
# ...

# %%
days_20=df.last("20D")
days_20
# Out:
# C:\Users\rajes\AppData\Local\Temp\ipykernel_9668\3923228676.py:1: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   days_20=df.last("20D")
#                      Order_Id Customer_Name  Customer_Id  \
# Pur_Date
# 2020-02-01 15:00:00     10542         Mohan           24
# 2020-02-01 16:00:00     10543    Nireekshan            1
# 2020-02-01 17:00:00     10544   Mallikarjun           13
# 2020-02-01 18:00:00     10545     Madhurima            7
# 2020-02-01 19:00:00     10546     Madhurima            7
# ...                       ...           ...          ...
# 2020-02-21 10:00:00     11017       Karteek            4
# 2020-02-21 11:00:00     11018         Vinay           10
# 2020-02-21 12:00:00     11019       Neelima           19
# 2020-02-21 13:00:00     11020        Siddhu           18
# 2020-02-21 14:00:00     11021         Tarun           11
#
# ...

# %%
import pandas as pd
df=pd.read_csv("sales7_dates.csv",parse_dates=["Pur_Date"])
df
# Out:
#       Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0         1023         Venki           15            27in FHD Monitor
# 1         1024    Chaithanya           14                   iPhone 11
# 2         1025        Shahid           20  Bose SoundSport Headphones
# 3         1026         Veeru            3        Apple iPad 10.2-inch
# 4         1027          Venu           23                Google Phone
# ...        ...           ...          ...                         ...
# 9994     11017       Karteek            4                20in Monitor
# 9995     11018         Vinay           10    Apple Airpods Headphones
# 9996     11019       Neelima           19      LG ThinQ Refrigerator
# 9997     11020        Siddhu           18                   iPhone 7s
# 9998     11021         Tarun           11      34in Ultrawide Monitor
#
#       Product_Cost            Pur_Date
# 0            59000 2019-01-01 00:00:00
# 1            69000 2019-01-01 01:00:00
# ...

# %%
df["Pur_Date"].dt.year
# Out:
# 0       2019
# 1       2019
# 2       2019
# 3       2019
# 4       2019
#         ...
# 9994    2020
# 9995    2020
# 9996    2020
# 9997    2020
# 9998    2020
# Name: Pur_Date, Length: 9999, dtype: int32

# %%
df["Pur_Date"].dt.month
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9994    2
# 9995    2
# 9996    2
# 9997    2
# 9998    2
# Name: Pur_Date, Length: 9999, dtype: int32

# %%
df["Pur_Date"].dt.day
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 9994    21
# 9995    21
# 9996    21
# 9997    21
# 9998    21
# Name: Pur_Date, Length: 9999, dtype: int32

# %%
df
# Out:
#       Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0         1023         Venki           15            27in FHD Monitor
# 1         1024    Chaithanya           14                   iPhone 11
# 2         1025        Shahid           20  Bose SoundSport Headphones
# 3         1026         Veeru            3        Apple iPad 10.2-inch
# 4         1027          Venu           23                Google Phone
# ...        ...           ...          ...                         ...
# 9994     11017       Karteek            4                20in Monitor
# 9995     11018         Vinay           10    Apple Airpods Headphones
# 9996     11019       Neelima           19      LG ThinQ Refrigerator
# 9997     11020        Siddhu           18                   iPhone 7s
# 9998     11021         Tarun           11      34in Ultrawide Monitor
#
#       Product_Cost            Pur_Date
# 0            59000 2019-01-01 00:00:00
# 1            69000 2019-01-01 01:00:00
# ...

# %%
df["year"]=df["Pur_Date"].dt.year
df["month"]=df["Pur_Date"].dt.month
df["day"]=df["Pur_Date"].dt.day
print(df.to_string())
# Out:
#       Order_Id Customer_Name  Customer_Id                Product_Name  Product_Cost            Pur_Date  year  month  day
# 0         1023         Venki           15            27in FHD Monitor         59000 2019-01-01 00:00:00  2019      1    1
# 1         1024    Chaithanya           14                   iPhone 11         69000 2019-01-01 01:00:00  2019      1    1
# 2         1025        Shahid           20  Bose SoundSport Headphones         65999 2019-01-01 02:00:00  2019      1    1
# 3         1026         Veeru            3        Apple iPad 10.2-inch         63999 2019-01-01 03:00:00  2019      1    1
# 4         1027          Venu           23                Google Phone         63999 2019-01-01 04:00:00  2019      1    1
# 5         1028        Daniel            6      Samsung Galaxy S9 Plus         63999 2019-01-01 05:00:00  2019      1    1
# 6         1029          Venu           23                   iPhone 11         61000 2019-01-01 06:00:00  2019      1    1
# ...

# %%
df["Pur_Date"].dt.month_name()
# Out:
# 0        January
# 1        January
# 2        January
# 3        January
# 4        January
#           ...
# 9994    February
# 9995    February
# 9996    February
# 9997    February
# 9998    February
# Name: Pur_Date, Length: 9999, dtype: object

# %%
df["Pur_Date"].dt.weekday
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9994    4
# 9995    4
# 9996    4
# 9997    4
# 9998    4
# Name: Pur_Date, Length: 9999, dtype: int32

# %%
df["Pur_Date"].dt.day_name()
# Out:
# 0       Tuesday
# 1       Tuesday
# 2       Tuesday
# 3       Tuesday
# 4       Tuesday
#          ...
# 9994     Friday
# 9995     Friday
# 9996     Friday
# 9997     Friday
# 9998     Friday
# Name: Pur_Date, Length: 9999, dtype: object
